# %% [markdown]
# # Mapas

# %%
#1.  Folium - La mas popular y facil
import folium

# Mapa basico
m = folium.Map(location=[4.6097, -74.0817], zoom_start=10) #Bogotá
m.save('mapa.html')
m # En Jupyter  se muestra directamente
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_39dac1ac9da6a60737a62ac5330739fa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_39dac1ac9da6a60737a62ac5330739fa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_39dac1ac9da6a60737a62ac5330739fa = L.map(
#                 &quot;map_39dac1ac9da6a60737a62ac5330739fa&quot;,
#                 {
#                     center: [4.6097, -74.0817],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_46eb0e6bfda1cd14de41c9f8e36acc8c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_46eb0e6bfda1cd14de41c9f8e36acc8c.addTo(map_39dac1ac9da6a60737a62ac5330739fa);
#
#
#             tile_layer_46eb0e6bfda1cd14de41c9f8e36acc8c.addTo(map_39dac1ac9da6a60737a62ac5330739fa);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 2. Plotly -Mapas interactivos avanzados

import plotly.graph_objects as go
import plotly.express as px

# Mapa con marcadores
fig = go.Figure(go.Scattermapbox (
   lat=[4.6097],
   lon=[-74.0817],
   mode='markers',
   marker=dict(size=14, color= 'green'),
   text=['Bogota'],
))

fig.update_layout(
    mapbox_style="open-street-main",
    mapbox=dict(center=dict(lat=4.6097, lon=-74.0817), zoom=10),
    margin={"r":0,"t":0,"b":0}
)
fig.show()
# Out:
# C:\Users\Aprendiz\AppData\Local\Temp\ipykernel_14232\3288012877.py:7: DeprecationWarning:
#
# *scattermapbox* is deprecated! Use *scattermap* instead. Learn more at: https://plotly.com/python/mapbox-to-maplibre/

# %%
## 2. Folium

import folium

# Mapa basico de colombia
m = folium.Map(location=[4.6, -74.08], zoom_start=6)

# Agregar marcadores de ciudades principales
ciudades = {
    'Bogota': [4.6097, -74.0817],
    'Santa Marta': [11.2408, -74.1990],
    'Bucaramanga': [7.1254, -73.1198],
    'Medellin': [6.2442, -75.5812],
    'Cali': [3.4516, -76.5320],
    'Barranquilla': [10.9685, -74.7813],
    'Cartagena': [10.3910, -75.4794]
}

for ciudad, coords in ciudades.items():
    folium.Marker(
        coords,
        popup=ciudad,
        tooltip=ciudad,
        icon=folium.Icon(color='red', icon='info-sign')
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_faefdbe12796b828005a129b5bcec12f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_faefdbe12796b828005a129b5bcec12f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_faefdbe12796b828005a129b5bcec12f = L.map(
#                 &quot;map_faefdbe12796b828005a129b5bcec12f&quot;,
#                 {
#                     center: [4.6, -74.08],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dd7b8fcf1ce5e9c7170c61df488d15df = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dd7b8fcf1ce5e9c7170c61df488d15df.addTo(map_faefdbe12796b828005a129b5bcec12f);
#
#
#             var marker_76c8c033dd7880bc41366f61806aff10 = L.marker(
#                 [4.6097, -74.0817],
#                 {
# }
#             ).addTo(map_faefdbe12796b828005a129b5bcec12f);
#
#
#             var icon_46278efda33c57280a177b65adac3bc9 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_6881d266ff6a06290a1a233987fd3316 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a462ff2ebec07c4bb1b394652781bb0c = $(`&lt;div id=&quot;html_a462ff2ebec07c4bb1b394652781bb0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bogota&lt;/div&gt;`)[0];
#                 popup_6881d266ff6a06290a1a233987fd3316.setContent(html_a462ff2ebec07c4bb1b394652781bb0c);
#
#
#
#         marker_76c8c033dd7880bc41366f61806aff10.bindPopup(popup_6881d266ff6a06290a1a233987fd3316)
#         ;
#
#
#
#
#             marker_76c8c033dd7880bc41366f61806aff10.bindTooltip(
#                 `&lt;div&gt;
#                      Bogota
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_76c8c033dd7880bc41366f61806aff10.setIcon(icon_46278efda33c57280a177b65adac3bc9);
#
#
#             var marker_a1df1b82b69b16a57a51bbfd1b4d3905 = L.marker(
#                 [11.2408, -74.199],
#                 {
# }
#             ).addTo(map_faefdbe12796b828005a129b5bcec12f);
#
#
#             var icon_96e5625ca1956d829d1f7359495803d4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_81520e5eba9f2a23fa6b56cccc69d17e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f77b1b0409c43da1b8f2d26afae7789c = $(`&lt;div id=&quot;html_f77b1b0409c43da1b8f2d26afae7789c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Santa Marta&lt;/div&gt;`)[0];
#                 popup_81520e5eba9f2a23fa6b56cccc69d17e.setContent(html_f77b1b0409c43da1b8f2d26afae7789c);
#
#
#
#         marker_a1df1b82b69b16a57a51bbfd1b4d3905.bindPopup(popup_81520e5eba9f2a23fa6b56cccc69d17e)
#         ;
#
#
#
#
#             marker_a1df1b82b69b16a57a51bbfd1b4d3905.bindTooltip(
#                 `&lt;div&gt;
#                      Santa Marta
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_a1df1b82b69b16a57a51bbfd1b4d3905.setIcon(icon_96e5625ca1956d829d1f7359495803d4);
#
#
#             var marker_2897d0f389fdede769377a2bf0602333 = L.marker(
#                 [7.1254, -73.1198],
#                 {
# }
#             ).addTo(map_faefdbe12796b828005a129b5bcec12f);
#
#
#             var icon_b0d565e4b2eb557c5f6e2549ab666190 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_000e2626b6ef927d4f4ff374a243fd1a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a1dbbfa1af7b28586ff2730c5dca07f7 = $(`&lt;div id=&quot;html_a1dbbfa1af7b28586ff2730c5dca07f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bucaramanga&lt;/div&gt
